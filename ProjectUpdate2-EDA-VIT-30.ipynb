# %% [markdown]
# ## Desription

# %% [markdown]
# -  Images are categorized based on the emotion shown in the facial expressions (happiness, neutral, sadness, anger, surprise, disgust, fear).
# -  We need to design a CNN which will classify images based on followinf facial expression

# %%
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# defining dir variables 
root_dir = './data/'
train_dir = root_dir + 'train/'
test_dir = root_dir + 'test/'

# %% [markdown]
# ##### Target labels in dataset

# %%
target_var = os.listdir(train_dir)
target_var
# Out:
# ['happy', 'sad', 'fearful', 'neutral', 'angry', 'disgusted', 'surprised']

# %% [markdown]
# ##### Sample Images

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 7, figsize=(20,8))
for i in range(len(target_var)):
    d = train_dir+target_var[i]+'/'+os.listdir(train_dir+target_var[i]+'/')[0]
    axes[i].imshow( plt.imread(d) )
    axes[i].set_title(target_var[i])
plt.show()

# %% [markdown]
# ##### EDA

# %%
x_train = np.array([ len(os.listdir(train_dir+i+'/')) for i in target_var ])
x_test = np.array([ len(os.listdir(test_dir+i+'/')) for i in target_var ])
label = target_var
  
fig, axes = plt.subplots(1, 2, figsize=(8,4))
axes[0].pie(x_train, labels=label, autopct='%1.1f%%', startangle=90)
axes[1].pie(x_test, labels=label, autopct='%1.1f%%',shadow=True, startangle=90)
axes[0].set_title('Train')
axes[1].set_title('Test')
plt.show()

for i in target_var:
    print('Emotion : ' + i )
    print('\tTraining : ' + str(len(os.listdir(train_dir+i+'/'))) +'\n\t Testing : ' + str(len(os.listdir(test_dir+i+'/'))))
# Out:
# Emotion : happy
# 	Training : 2143
# 	 Testing : 1774
# Emotion : sad
# 	Training : 1478
# 	 Testing : 1247
# Emotion : fearful
# 	Training : 1362
# 	 Testing : 1024
# Emotion : neutral
# 	Training : 1502
# 	 Testing : 1233
# Emotion : angry
# 	Training : 1352
# 	 Testing : 958
# Emotion : disgusted
# 	Training : 437
# 	 Testing : 111
# Emotion : surprised
# 	Training : 1039
# 	 Testing : 831

# %%
train_count = {expression: len(os.listdir(os.path.join(train_dir, expression))) 
                for expression in os.listdir(train_dir)}
train_count_df = pd.DataFrame(train_count, index=['train'])

test_count = {expression: len(os.listdir(os.path.join(test_dir, expression))) 
               for expression in os.listdir(test_dir)}
test_count_df = pd.DataFrame(test_count, index=['test'])

# %%
# Plotting data distribution
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
train_count_df.transpose().plot(kind='bar', ax=plt.gca())
plt.title('Train Data')
plt.xlabel('Emotion')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
test_count_df.transpose().plot(kind='bar', ax=plt.gca())
plt.title('Test Data')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - Male and Females Count.

# %%
import torch
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from torch.utils.data import random_split

# Setup directories
train_dir = './data/train'
test_dir = './data/test'

# Define image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Load datasets
train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)

# Define the size of the dataset and split
total_train = len(train_dataset)
val_size = int(0.2 * total_train)
train_size = total_train - val_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

def show_images(dataset, indices, num_images=6):
    fig, axes = plt.subplots(1, num_images, figsize=(10, 5))
    for i, idx in enumerate(indices[:num_images]):
        img, label = dataset[idx]
        ax = axes[i]
        ax.imshow(img.permute(1, 2, 0))
        ax.axis('off')
        ax.set_title(train_dataset.classes[label])
    plt.show()

# Display a few images from the train dataset
indices = [i for i, _ in enumerate(train_dataset)]
show_images(train_dataset, indices)

# %%
total_train
# Out:
# 9307

# %%
from torch.utils.data import DataLoader

# Data Loaders
batch_size = 16
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import timm

# Initialize the model
device = torch.device('cpu')
num_classes = len(train_dataset.classes)
model = timm.create_model('vit_small_patch16_224', pretrained=True, num_classes=num_classes)
model = model.to(device)

# %%
import torch
import torch.nn as nn
from torch.optim import AdamW

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=5e-5)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10):
    model.train()
    training_stats = []
    
    for epoch in range(num_epochs):
        total_train_loss = 0
        total_val_loss = 0
        total_val_accuracy = 0
        
        # Training phase
        for batch_index, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

            # Each batch
            if (batch_index + 1) % 10 == 0:
                print(f"Epoch {epoch+1}, Batch {batch_index+1}: Train Loss so far: {total_train_loss / (batch_index + 1)}")

        # Validation phase
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for batch_index, (images, labels) in enumerate(val_loader):
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                total_val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                # Validation update for each batch
                if (batch_index + 1) % 10 == 0:
                    print(f"Epoch {epoch+1}, Validation Batch {batch_index+1}: Validation Loss so far: {total_val_loss / (batch_index + 1)}")

            accuracy = 100 * correct / total
            total_val_accuracy = accuracy

        # Store statistics
        training_stats.append({
            'train_loss': total_train_loss / len(train_loader),
            'val_loss': total_val_loss / len(val_loader),
            'val_accuracy': total_val_accuracy
        })
        
        print(f"Epoch {epoch+1}: Train Loss: {total_train_loss / len(train_loader)}, Val Loss: {total_val_loss / len(val_loader)}, Val Accuracy: {total_val_accuracy}%")
    
    return training_stats

# Call the training function
training_stats = train_model(model, criterion, optimizer, train_loader, val_loader)
# Out:
# Epoch 1, Batch 10: Train Loss so far: 2.2034121632575987
# Epoch 1, Batch 20: Train Loss so far: 2.0131736278533934
# Epoch 1, Batch 30: Train Loss so far: 1.9563568512598672
# Epoch 1, Batch 40: Train Loss so far: 1.8766206681728363
# Epoch 1, Batch 50: Train Loss so far: 1.7890774607658386
# Epoch 1, Batch 60: Train Loss so far: 1.7272007743517557
# Epoch 1, Batch 70: Train Loss so far: 1.704851954323905
# Epoch 1, Batch 80: Train Loss so far: 1.6860297977924348
# Epoch 1, Batch 90: Train Loss so far: 1.6551964640617371
# Epoch 1, Batch 100: Train Loss so far: 1.6319541668891906
# Epoch 1, Batch 110: Train Loss so far: 1.6191447333856062
# Epoch 1, Batch 120: Train Loss so far: 1.601790377497673
# Epoch 1, Batch 130: Train Loss so far: 1.5851740479469298
# Epoch 1, Batch 140: Train Loss so far: 1.5679565046514783
# Epoch 1, Batch 150: Train Loss so far: 1.5522942340373993
# Epoch 1, Batch 160: Train Loss so far: 1.5385337684303522
# Epoch 1, Batch 170: Train Loss so far: 1.5266143143177033
# Epoch 1, Batch 180: Train Loss so far: 1.5131315661801232
# Epoch 1, Batch 190: Train Loss so far: 1.5031173586845399
# Epoch 1, Batch 200: Train Loss so far: 1.4971990761160852
# Epoch 1, Batch 210: Train Loss so far: 1.4844947604905991
# Epoch 1, Batch 220: Train Loss so far: 1.4749933110042053
# Epoch 1, Batch 230: Train Loss so far: 1.4656382770641991
# Epoch 1, Batch 240: Train Loss so far: 1.4577406195302804
# Epoch 1, Batch 250: Train Loss so far: 1.4522710115909576
# Epoch 1, Batch 260: Train Loss so far: 1.4441334103162473
# Epoch 1, Batch 270: Train Loss so far: 1.4360085880314861
# Epoch 1, Batch 280: Train Loss so far: 1.4282528581363814
# Epoch 1, Batch 290: Train Loss so far: 1.4190340858081292
# Epoch 1, Batch 300: Train Loss so far: 1.4123586360613505
# Epoch 1, Batch 310: Train Loss so far: 1.403818190482355
# Epoch 1, Batch 320: Train Loss so far: 1.3955554984509946
# Epoch 1, Batch 330: Train Loss so far: 1.389038225556865
# Epoch 1, Batch 340: Train Loss so far: 1.3803622776971143
# Epoch 1, Batch 350: Train Loss so far: 1.3764187569277626
# Epoch 1, Batch 360: Train Loss so far: 1.3656289820869765
# Epoch 1, Batch 370: Train Loss so far: 1.3604353919222547
# Epoch 1, Batch 380: Train Loss so far: 1.3569785748657428
# Epoch 1, Batch 390: Train Loss so far: 1.3526123986794398
# Epoch 1, Batch 400: Train Loss so far: 1.3463147167861462
# Epoch 1, Batch 410: Train Loss so far: 1.342445801380204
# Epoch 1, Batch 420: Train Loss so far: 1.338865731869425
# Epoch 1, Batch 430: Train Loss so far: 1.3347667548545572
# Epoch 1, Batch 440: Train Loss so far: 1.3284816873344507
# Epoch 1, Batch 450: Train Loss so far: 1.3279662711090512
# Epoch 1, Batch 460: Train Loss so far: 1.32777237114699
# Epoch 1, Validation Batch 10: Validation Loss so far: 1.1246013522148133
# Epoch 1, Validation Batch 20: Validation Loss so far: 1.2078610599040984
# Epoch 1, Validation Batch 30: Validation Loss so far: 1.189331595102946
# Epoch 1, Validation Batch 40: Validation Loss so far: 1.2092178925871848
# Epoch 1, Validation Batch 50: Validation Loss so far: 1.1755234861373902
# Epoch 1, Validation Batch 60: Validation Loss so far: 1.1960642139116924
# Epoch 1, Validation Batch 70: Validation Loss so far: 1.1893946962697166
# Epoch 1, Validation Batch 80: Validation Loss so far: 1.1869725860655307
# Epoch 1, Validation Batch 90: Validation Loss so far: 1.1813990824752383
# Epoch 1, Validation Batch 100: Validation Loss so far: 1.1688004642724992
# Epoch 1, Validation Batch 110: Validation Loss so far: 1.1659946517510849
# Epoch 1: Train Loss: 1.327215302911439, Val Loss: 1.1664126163873918, Val Accuracy: 56.689951638903814%
# Epoch 2, Batch 10: Train Loss so far: 1.019902515411377
# Epoch 2, Batch 20: Train Loss so far: 0.9929926186800003
# Epoch 2, Batch 30: Train Loss so far: 0.9754912157853445
# Epoch 2, Batch 40: Train Loss so far: 0.9423033013939858
# Epoch 2, Batch 50: Train Loss so far: 0.9359390795230865
# Epoch 2, Batch 60: Train Loss so far: 0.9514196634292602
# Epoch 2, Batch 70: Train Loss so far: 0.9568256088665553
# Epoch 2, Batch 80: Train Loss so far: 0.9334492430090904
# Epoch 2, Batch 90: Train Loss so far: 0.9299994375970628
# Epoch 2, Batch 100: Train Loss so far: 0.9333717197179794
# Epoch 2, Batch 110: Train Loss so far: 0.9317628069357439
# Epoch 2, Batch 120: Train Loss so far: 0.9285478288928668
# Epoch 2, Batch 130: Train Loss so far: 0.94313366321417
# Epoch 2, Batch 140: Train Loss so far: 0.9526593497821263
# Epoch 2, Batch 150: Train Loss so far: 0.9595805160204569
# Epoch 2, Batch 160: Train Loss so far: 0.959258121624589
# Epoch 2, Batch 170: Train Loss so far: 0.9581619438003092
# Epoch 2, Batch 180: Train Loss so far: 0.9548225652840402
# Epoch 2, Batch 190: Train Loss so far: 0.9608369508856222
# Epoch 2, Batch 200: Train Loss so far: 0.9583689562976361
# Epoch 2, Batch 210: Train Loss so far: 0.9507006351436887
# Epoch 2, Batch 220: Train Loss so far: 0.9511853335933251
# Epoch 2, Batch 230: Train Loss so far: 0.9481060703163562
# Epoch 2, Batch 240: Train Loss so far: 0.9460340145975351
# Epoch 2, Batch 250: Train Loss so far: 0.9513081151247025
# Epoch 2, Batch 260: Train Loss so far: 0.9546681774350313
# Epoch 2, Batch 270: Train Loss so far: 0.954283689017649
# Epoch 2, Batch 280: Train Loss so far: 0.9565985518906798
# Epoch 2, Batch 290: Train Loss so far: 0.9540045213082741
# Epoch 2, Batch 300: Train Loss so far: 0.9486679963270823
# Epoch 2, Batch 310: Train Loss so far: 0.9479192503036992
# Epoch 2, Batch 320: Train Loss so far: 0.9488079238682985
# Epoch 2, Batch 330: Train Loss so far: 0.9445057392120362
# Epoch 2, Batch 340: Train Loss so far: 0.9393760646090789
# Epoch 2, Batch 350: Train Loss so far: 0.936326128925596
# Epoch 2, Batch 360: Train Loss so far: 0.9372174315982394
# Epoch 2, Batch 370: Train Loss so far: 0.9365003742076256
# Epoch 2, Batch 380: Train Loss so far: 0.9349501089045876
# Epoch 2, Batch 390: Train Loss so far: 0.9360715899712
# Epoch 2, Batch 400: Train Loss so far: 0.9362747268378735
# Epoch 2, Batch 410: Train Loss so far: 0.9350465021482328
# Epoch 2, Batch 420: Train Loss so far: 0.9350877204111644
# Epoch 2, Batch 430: Train Loss so far: 0.9343709305275318
# Epoch 2, Batch 440: Train Loss so far: 0.9366266207261519
# Epoch 2, Batch 450: Train Loss so far: 0.9356480393807093
# Epoch 2, Batch 460: Train Loss so far: 0.9377918083382689
# Epoch 2, Validation Batch 10: Validation Loss so far: 1.0154264569282532
# Epoch 2, Validation Batch 20: Validation Loss so far: 1.0956928253173828
# Epoch 2, Validation Batch 30: Validation Loss so far: 1.0811391075452168
# Epoch 2, Validation Batch 40: Validation Loss so far: 1.1157908216118813
# Epoch 2, Validation Batch 50: Validation Loss so far: 1.0911682367324829
# Epoch 2, Validation Batch 60: Validation Loss so far: 1.1175142804781595
# Epoch 2, Validation Batch 70: Validation Loss so far: 1.119936909845897
# Epoch 2, Validation Batch 80: Validation Loss so far: 1.1157306000590324
# Epoch 2, Validation Batch 90: Validation Loss so far: 1.1133473561869727
# Epoch 2, Validation Batch 100: Validation Loss so far: 1.1013439637422562
# Epoch 2, Validation Batch 110: Validation Loss so far: 1.103523879701441
# Epoch 2: Train Loss: 0.9399169539561087, Val Loss: 1.1013739531875675, Val Accuracy: 58.57066093498119%
# Epoch 3, Batch 10: Train Loss so far: 0.7150396764278412
# Epoch 3, Batch 20: Train Loss so far: 0.6339414209127426
# Epoch 3, Batch 30: Train Loss so far: 0.6366976728041966
# Epoch 3, Batch 40: Train Loss so far: 0.6614373497664928
# Epoch 3, Batch 50: Train Loss so far: 0.6800991982221604
# Epoch 3, Batch 60: Train Loss so far: 0.6477587655186653
# Epoch 3, Batch 70: Train Loss so far: 0.6747158931834357
# Epoch 3, Batch 80: Train Loss so far: 0.6504214886575937
# Epoch 3, Batch 90: Train Loss so far: 0.6568570123778449
# Epoch 3, Batch 100: Train Loss so far: 0.6608824265003205
# Epoch 3, Batch 110: Train Loss so far: 0.6584374104033817
# Epoch 3, Batch 120: Train Loss so far: 0.6550030903269847
# Epoch 3, Batch 130: Train Loss so far: 0.6552439225407747
# Epoch 3, Batch 140: Train Loss so far: 0.6582099360014712
# Epoch 3, Batch 150: Train Loss so far: 0.6585408269365629
# Epoch 3, Batch 160: Train Loss so far: 0.6599213029257953
# Epoch 3, Batch 170: Train Loss so far: 0.6638094999334392
# Epoch 3, Batch 180: Train Loss so far: 0.6651476344300641
# Epoch 3, Batch 190: Train Loss so far: 0.6689439793166362
# Epoch 3, Batch 200: Train Loss so far: 0.6751621416956186
# Epoch 3, Batch 210: Train Loss so far: 0.6774014326078551
# Epoch 3, Batch 220: Train Loss so far: 0.6756014376878738
# Epoch 3, Batch 230: Train Loss so far: 0.6753911903370982
# Epoch 3, Batch 240: Train Loss so far: 0.6760275829583406
# Epoch 3, Batch 250: Train Loss so far: 0.6752067918181419
# Epoch 3, Batch 260: Train Loss so far: 0.675435667943496
# Epoch 3, Batch 270: Train Loss so far: 0.6743293331177146
# Epoch 3, Batch 280: Train Loss so far: 0.6724722696734327
# Epoch 3, Batch 290: Train Loss so far: 0.6724442113576264
# Epoch 3, Batch 300: Train Loss so far: 0.6728753812611104
# Epoch 3, Batch 310: Train Loss so far: 0.6777317828228396
# Epoch 3, Batch 320: Train Loss so far: 0.6803759726230055
# Epoch 3, Batch 330: Train Loss so far: 0.6796495228554263
# Epoch 3, Batch 340: Train Loss so far: 0.6781086617971168
# Epoch 3, Batch 350: Train Loss so far: 0.6807401582598687
# Epoch 3, Batch 360: Train Loss so far: 0.6809621495091253
# Epoch 3, Batch 370: Train Loss so far: 0.6790853162472312
# Epoch 3, Batch 380: Train Loss so far: 0.6756327635755665
# Epoch 3, Batch 390: Train Loss so far: 0.6743524840626961
# Epoch 3, Batch 400: Train Loss so far: 0.6754080729559064
# Epoch 3, Batch 410: Train Loss so far: 0.6738663923813075
# Epoch 3, Batch 420: Train Loss so far: 0.673512026632116
# Epoch 3, Batch 430: Train Loss so far: 0.6717722406567529
# Epoch 3, Batch 440: Train Loss so far: 0.6710633926432241
# Epoch 3, Batch 450: Train Loss so far: 0.6720823355846934
# Epoch 3, Batch 460: Train Loss so far: 0.6755348257072594
# Epoch 3, Validation Batch 10: Validation Loss so far: 1.065020489692688
# Epoch 3, Validation Batch 20: Validation Loss so far: 1.1657827854156495
# Epoch 3, Validation Batch 30: Validation Loss so far: 1.1283818364143372
# Epoch 3, Validation Batch 40: Validation Loss so far: 1.1532522156834601
# Epoch 3, Validation Batch 50: Validation Loss so far: 1.1232777684926987
# Epoch 3, Validation Batch 60: Validation Loss so far: 1.1626269802451135
# Epoch 3, Validation Batch 70: Validation Loss so far: 1.1648967960051129
# Epoch 3, Validation Batch 80: Validation Loss so far: 1.16165860183537
# Epoch 3, Validation Batch 90: Validation Loss so far: 1.1540153940518698
# Epoch 3, Validation Batch 100: Validation Loss so far: 1.148563169836998
# Epoch 3, Validation Batch 110: Validation Loss so far: 1.1534178495407104
# Epoch 3: Train Loss: 0.6769413195646372, Val Loss: 1.1522689268120334, Val Accuracy: 61.5260612573885%
# Epoch 4, Batch 10: Train Loss so far: 0.4065906196832657
# Epoch 4, Batch 20: Train Loss so far: 0.438515841960907
# Epoch 4, Batch 30: Train Loss so far: 0.3990391289194425
# Epoch 4, Batch 40: Train Loss so far: 0.3830276243388653
# Epoch 4, Batch 50: Train Loss so far: 0.36595926105976107
# Epoch 4, Batch 60: Train Loss so far: 0.3532072218755881
# Epoch 4, Batch 70: Train Loss so far: 0.3598031942333494
# Epoch 4, Batch 80: Train Loss so far: 0.3726049972698092
# Epoch 4, Batch 90: Train Loss so far: 0.38578364269600973
# Epoch 4, Batch 100: Train Loss so far: 0.3787209023535252
# Epoch 4, Batch 110: Train Loss so far: 0.37593476751988586
# Epoch 4, Batch 120: Train Loss so far: 0.3691821545983354
# Epoch 4, Batch 130: Train Loss so far: 0.3716913677752018
# Epoch 4, Batch 140: Train Loss so far: 0.37245356818395003
# Epoch 4, Batch 150: Train Loss so far: 0.37717517927289007
# Epoch 4, Batch 160: Train Loss so far: 0.37704323600046336
# Epoch 4, Batch 170: Train Loss so far: 0.3780809550162624
# Epoch 4, Batch 180: Train Loss so far: 0.383334834418363
# Epoch 4, Batch 190: Train Loss so far: 0.38351133493216416
# Epoch 4, Batch 200: Train Loss so far: 0.39313739266246556
# Epoch 4, Batch 210: Train Loss so far: 0.3948843826850255
# Epoch 4, Batch 220: Train Loss so far: 0.3952473028139635
# Epoch 4, Batch 230: Train Loss so far: 0.3959076157082682
# Epoch 4, Batch 240: Train Loss so far: 0.3989432438587149
# Epoch 4, Batch 250: Train Loss so far: 0.40415889823436735
# Epoch 4, Batch 260: Train Loss so far: 0.40776044084475593
# Epoch 4, Batch 270: Train Loss so far: 0.40871008985020496
# Epoch 4, Batch 280: Train Loss so far: 0.40990578433764835
# Epoch 4, Batch 290: Train Loss so far: 0.4072993450894438
# Epoch 4, Batch 300: Train Loss so far: 0.4062150276452303
# Epoch 4, Batch 310: Train Loss so far: 0.41060774919967497
# Epoch 4, Batch 320: Train Loss so far: 0.41246225459035485
# Epoch 4, Batch 330: Train Loss so far: 0.41169663204839735
# Epoch 4, Batch 340: Train Loss so far: 0.40970448546988125
# Epoch 4, Batch 350: Train Loss so far: 0.4116747698400702
# Epoch 4, Batch 360: Train Loss so far: 0.41315562044166854
# Epoch 4, Batch 370: Train Loss so far: 0.41328589020145906
# Epoch 4, Batch 380: Train Loss so far: 0.41411963879669966
# Epoch 4, Batch 390: Train Loss so far: 0.4150185457215859
# Epoch 4, Batch 400: Train Loss so far: 0.41674331372603773
# Epoch 4, Batch 410: Train Loss so far: 0.4179717507849379
# Epoch 4, Batch 420: Train Loss so far: 0.42085739890379564
# Epoch 4, Batch 430: Train Loss so far: 0.42110803718137185
# Epoch 4, Batch 440: Train Loss so far: 0.42133280790664934
# Epoch 4, Batch 450: Train Loss so far: 0.4221545828713311
# Epoch 4, Batch 460: Train Loss so far: 0.42311927935351495
# Epoch 4, Validation Batch 10: Validation Loss so far: 1.2762442350387573
# Epoch 4, Validation Batch 20: Validation Loss so far: 1.4975163698196412
# Epoch 4, Validation Batch 30: Validation Loss so far: 1.4800836940606434
# Epoch 4, Validation Batch 40: Validation Loss so far: 1.501487421989441
# Epoch 4, Validation Batch 50: Validation Loss so far: 1.494068936109543
# Epoch 4, Validation Batch 60: Validation Loss so far: 1.5195653567711511
# Epoch 4, Validation Batch 70: Validation Loss so far: 1.497661533526012
# Epoch 4, Validation Batch 80: Validation Loss so far: 1.4953673273324966
# Epoch 4, Validation Batch 90: Validation Loss so far: 1.4952843970722622
# Epoch 4, Validation Batch 100: Validation Loss so far: 1.4814151459932328
# Epoch 4, Validation Batch 110: Validation Loss so far: 1.478565641966733
# Epoch 4: Train Loss: 0.4261060415931014, Val Loss: 1.4737976677397377, Val Accuracy: 57.87211176786674%
# Epoch 5, Batch 10: Train Loss so far: 0.2974338874220848
# Epoch 5, Batch 20: Train Loss so far: 0.2814941816031933
# Epoch 5, Batch 30: Train Loss so far: 0.24607726087172827
# Epoch 5, Batch 40: Train Loss so far: 0.24358731117099525
# Epoch 5, Batch 50: Train Loss so far: 0.24807511270046234
# Epoch 5, Batch 60: Train Loss so far: 0.24011385987202327
# Epoch 5, Batch 70: Train Loss so far: 0.22931970687849182
# Epoch 5, Batch 80: Train Loss so far: 0.22513038963079451
# Epoch 5, Batch 90: Train Loss so far: 0.2187761620928844
# Epoch 5, Batch 100: Train Loss so far: 0.2216378539428115
# Epoch 5, Batch 110: Train Loss so far: 0.2227969987487251
# Epoch 5, Batch 120: Train Loss so far: 0.230286580696702
# Epoch 5, Batch 130: Train Loss so far: 0.227624734548422
# Epoch 5, Batch 140: Train Loss so far: 0.22303446850606373
# Epoch 5, Batch 150: Train Loss so far: 0.22282732327779134
# Epoch 5, Batch 160: Train Loss so far: 0.22272082851268352
# Epoch 5, Batch 170: Train Loss so far: 0.2220213978386977
# Epoch 5, Batch 180: Train Loss so far: 0.22129769455641507
# Epoch 5, Batch 190: Train Loss so far: 0.2196170703066807
# Epoch 5, Batch 200: Train Loss so far: 0.21636359536089003
# Epoch 5, Batch 210: Train Loss so far: 0.21593045428217877
# Epoch 5, Batch 220: Train Loss so far: 0.21516408306461843
# Epoch 5, Batch 230: Train Loss so far: 0.2175528491239833
# Epoch 5, Batch 240: Train Loss so far: 0.21748213404013464
# Epoch 5, Batch 250: Train Loss so far: 0.21657559856027364
# Epoch 5, Batch 260: Train Loss so far: 0.21469105156854942
# Epoch 5, Batch 270: Train Loss so far: 0.21806451251937284
# Epoch 5, Batch 280: Train Loss so far: 0.21860337295968618
# Epoch 5, Batch 290: Train Loss so far: 0.21858729497882826
# Epoch 5, Batch 300: Train Loss so far: 0.22148247419546047
# Epoch 5, Batch 310: Train Loss so far: 0.22214828521734284
# Epoch 5, Batch 320: Train Loss so far: 0.220782849797979
# Epoch 5, Batch 330: Train Loss so far: 0.22375395474108783
# Epoch 5, Batch 340: Train Loss so far: 0.22311174358953448
# Epoch 5, Batch 350: Train Loss so far: 0.22603734924324922
# Epoch 5, Batch 360: Train Loss so far: 0.22946552405547765
# Epoch 5, Batch 370: Train Loss so far: 0.23332574042315418
# Epoch 5, Batch 380: Train Loss so far: 0.237196016968473
# Epoch 5, Batch 390: Train Loss so far: 0.23962711710005236
# Epoch 5, Batch 400: Train Loss so far: 0.24173080577515066
# Epoch 5, Batch 410: Train Loss so far: 0.2417476910370879
# Epoch 5, Batch 420: Train Loss so far: 0.24405059176718905
# Epoch 5, Batch 430: Train Loss so far: 0.24263785747421343
# Epoch 5, Batch 440: Train Loss so far: 0.24398526768623427
# Epoch 5, Batch 450: Train Loss so far: 0.24608284434510602
# Epoch 5, Batch 460: Train Loss so far: 0.24685480796286594
# Epoch 5, Validation Batch 10: Validation Loss so far: 1.3330097317695617
# Epoch 5, Validation Batch 20: Validation Loss so far: 1.6009622991085053
# Epoch 5, Validation Batch 30: Validation Loss so far: 1.4900529325008391
# Epoch 5, Validation Batch 40: Validation Loss so far: 1.506859341263771
# Epoch 5, Validation Batch 50: Validation Loss so far: 1.457990778684616
# Epoch 5, Validation Batch 60: Validation Loss so far: 1.4968971421321233
# Epoch 5, Validation Batch 70: Validation Loss so far: 1.4814224660396575
# Epoch 5, Validation Batch 80: Validation Loss so far: 1.4556164897978305
# Epoch 5, Validation Batch 90: Validation Loss so far: 1.46167381339603
# Epoch 5, Validation Batch 100: Validation Loss so far: 1.4561441624164582
# Epoch 5, Validation Batch 110: Validation Loss so far: 1.4723679878494955
# Epoch 5: Train Loss: 0.24709270204629252, Val Loss: 1.4696103217255356, Val Accuracy: 59.86029016657711%
# Epoch 6, Batch 10: Train Loss so far: 0.15580899082124233
# Epoch 6, Batch 20: Train Loss so far: 0.16240698974579573
# Epoch 6, Batch 30: Train Loss so far: 0.14920279799650113
# Epoch 6, Batch 40: Train Loss so far: 0.16088188323192298
# Epoch 6, Batch 50: Train Loss so far: 0.1535452330671251
# Epoch 6, Batch 60: Train Loss so far: 0.15516877868212758
# Epoch 6, Batch 70: Train Loss so far: 0.1474407228907304
# Epoch 6, Batch 80: Train Loss so far: 0.13993496502516792
# Epoch 6, Batch 90: Train Loss so far: 0.13777466376001637
# Epoch 6, Batch 100: Train Loss so far: 0.13243513739667834
# Epoch 6, Batch 110: Train Loss so far: 0.12832244582982225
# Epoch 6, Batch 120: Train Loss so far: 0.13049891553043078
# Epoch 6, Batch 130: Train Loss so far: 0.1280126656119067
# Epoch 6, Batch 140: Train Loss so far: 0.1262157819832542
# Epoch 6, Batch 150: Train Loss so far: 0.12495927914356192
# Epoch 6, Batch 160: Train Loss so far: 0.1237485037825536
# Epoch 6, Batch 170: Train Loss so far: 0.12303791506873334
# Epoch 6, Batch 180: Train Loss so far: 0.12169234790425333
# Epoch 6, Batch 190: Train Loss so far: 0.12172644326561376
# Epoch 6, Batch 200: Train Loss so far: 0.11969584040343761
# Epoch 6, Batch 210: Train Loss so far: 0.12220659832514467
# Epoch 6, Batch 220: Train Loss so far: 0.1198464851911095
# Epoch 6, Batch 230: Train Loss so far: 0.12056298108528489
# Epoch 6, Batch 240: Train Loss so far: 0.12124860953384389
# Epoch 6, Batch 250: Train Loss so far: 0.12157536019384861
# Epoch 6, Batch 260: Train Loss so far: 0.12257215517501419
# Epoch 6, Batch 270: Train Loss so far: 0.12337152907555854
# Epoch 6, Batch 280: Train Loss so far: 0.1234646603764434
# Epoch 6, Batch 290: Train Loss so far: 0.1238139330345238
# Epoch 6, Batch 300: Train Loss so far: 0.12605832304495077
# Epoch 6, Batch 310: Train Loss so far: 0.12471238185591516
# Epoch 6, Batch 320: Train Loss so far: 0.12416076268273173
# Epoch 6, Batch 330: Train Loss so far: 0.12669173376775827
# Epoch 6, Batch 340: Train Loss so far: 0.12810144339934648
# Epoch 6, Batch 350: Train Loss so far: 0.1296704044924783
# Epoch 6, Batch 360: Train Loss so far: 0.1299690122082312
# Epoch 6, Batch 370: Train Loss so far: 0.130552906602168
# Epoch 6, Batch 380: Train Loss so far: 0.13099007519133585
# Epoch 6, Batch 390: Train Loss so far: 0.13107676351180253
# Epoch 6, Batch 400: Train Loss so far: 0.1313904925796669
# Epoch 6, Batch 410: Train Loss so far: 0.132663334850449
# Epoch 6, Batch 420: Train Loss so far: 0.1332847903161088
# Epoch 6, Batch 430: Train Loss so far: 0.13507632243576959
# Epoch 6, Batch 440: Train Loss so far: 0.1396206940471364
# Epoch 6, Batch 450: Train Loss so far: 0.14103036453636983
# Epoch 6, Batch 460: Train Loss so far: 0.14307394755255107
# Epoch 6, Validation Batch 10: Validation Loss so far: 1.4741496741771698
# Epoch 6, Validation Batch 20: Validation Loss so far: 1.5983251720666884
# Epoch 6, Validation Batch 30: Validation Loss so far: 1.5901274025440215
# Epoch 6, Validation Batch 40: Validation Loss so far: 1.6685164734721183
# Epoch 6, Validation Batch 50: Validation Loss so far: 1.6046639275550842
# Epoch 6, Validation Batch 60: Validation Loss so far: 1.6463870485623677
# Epoch 6, Validation Batch 70: Validation Loss so far: 1.6419637279851096
# Epoch 6, Validation Batch 80: Validation Loss so far: 1.6276835910975933
# Epoch 6, Validation Batch 90: Validation Loss so far: 1.6324846022658879
# Epoch 6, Validation Batch 100: Validation Loss so far: 1.6278931045532226
# Epoch 6, Validation Batch 110: Validation Loss so far: 1.6407434013756839
# Epoch 6: Train Loss: 0.14322919443613438, Val Loss: 1.6267692956150088, Val Accuracy: 59.322944653412144%
# Epoch 7, Batch 10: Train Loss so far: 0.11611962337046862
# Epoch 7, Batch 20: Train Loss so far: 0.09020605413243174
# Epoch 7, Batch 30: Train Loss so far: 0.09601756315678359
# Epoch 7, Batch 40: Train Loss so far: 0.10096446457318961
# Epoch 7, Batch 50: Train Loss so far: 0.10148727171123027
# Epoch 7, Batch 60: Train Loss so far: 0.10458086095750332
# Epoch 7, Batch 70: Train Loss so far: 0.11305638563686184
# Epoch 7, Batch 80: Train Loss so far: 0.11228143739281223
# Epoch 7, Batch 90: Train Loss so far: 0.1137115568233033
# Epoch 7, Batch 100: Train Loss so far: 0.10772750922944396
# Epoch 7, Batch 110: Train Loss so far: 0.104888727189973
# Epoch 7, Batch 120: Train Loss so far: 0.10522881008607025
# Epoch 7, Batch 130: Train Loss so far: 0.10352339716269993
# Epoch 7, Batch 140: Train Loss so far: 0.1031142175496955
# Epoch 7, Batch 150: Train Loss so far: 0.10031159814757605
# Epoch 7, Batch 160: Train Loss so far: 0.09888702574244235
# Epoch 7, Batch 170: Train Loss so far: 0.09838819476118421
# Epoch 7, Batch 180: Train Loss so far: 0.09759395376830879
# Epoch 7, Batch 190: Train Loss so far: 0.10074419681914151
# Epoch 7, Batch 200: Train Loss so far: 0.10231465337565168
# Epoch 7, Batch 210: Train Loss so far: 0.10398959996223095
# Epoch 7, Batch 220: Train Loss so far: 0.10664651535917073
# Epoch 7, Batch 230: Train Loss so far: 0.10838181213475764
# Epoch 7, Batch 240: Train Loss so far: 0.106539106258424
# Epoch 7, Batch 250: Train Loss so far: 0.10592850015498698
# Epoch 7, Batch 260: Train Loss so far: 0.10541752392175392
# Epoch 7, Batch 270: Train Loss so far: 0.10383756514379962
# Epoch 7, Batch 280: Train Loss so far: 0.10309513049349854
# Epoch 7, Batch 290: Train Loss so far: 0.10312348739966622
# Epoch 7, Batch 300: Train Loss so far: 0.10414424376174186
# Epoch 7, Batch 310: Train Loss so far: 0.1070834489621883
# Epoch 7, Batch 320: Train Loss so far: 0.10724852003113483
# Epoch 7, Batch 330: Train Loss so far: 0.10697460956377626
# Epoch 7, Batch 340: Train Loss so far: 0.10800607461441199
# Epoch 7, Batch 350: Train Loss so far: 0.1076030919920387
# Epoch 7, Batch 360: Train Loss so far: 0.10830691779717906
# Epoch 7, Batch 370: Train Loss so far: 0.11083254496554366
# Epoch 7, Batch 380: Train Loss so far: 0.11173041403158814
# Epoch 7, Batch 390: Train Loss so far: 0.11289050780678503
# Epoch 7, Batch 400: Train Loss so far: 0.11272023625730071
# Epoch 7, Batch 410: Train Loss so far: 0.11403927124820923
# Epoch 7, Batch 420: Train Loss so far: 0.11541775898353773
# Epoch 7, Batch 430: Train Loss so far: 0.11596470666713579
# Epoch 7, Batch 440: Train Loss so far: 0.11561238742063076
# Epoch 7, Batch 450: Train Loss so far: 0.11530937514009161
# Epoch 7, Batch 460: Train Loss so far: 0.11581536424396884
# Epoch 7, Validation Batch 10: Validation Loss so far: 1.4807047545909882
# Epoch 7, Validation Batch 20: Validation Loss so far: 1.7070610135793687
# Epoch 7, Validation Batch 30: Validation Loss so far: 1.7006370027860005
# Epoch 7, Validation Batch 40: Validation Loss so far: 1.7246374368667603
# Epoch 7, Validation Batch 50: Validation Loss so far: 1.6892674720287324
# Epoch 7, Validation Batch 60: Validation Loss so far: 1.7502135982116063
# Epoch 7, Validation Batch 70: Validation Loss so far: 1.7380508661270142
# Epoch 7, Validation Batch 80: Validation Loss so far: 1.737493796646595
# Epoch 7, Validation Batch 90: Validation Loss so far: 1.7432423104842505
# Epoch 7, Validation Batch 100: Validation Loss so far: 1.7328661784529686
# Epoch 7, Validation Batch 110: Validation Loss so far: 1.7421313619071788
# Epoch 7: Train Loss: 0.11604272882611982, Val Loss: 1.7304765824069324, Val Accuracy: 59.75282106394412%
# Epoch 8, Batch 10: Train Loss so far: 0.04069255464710295
# Epoch 8, Batch 20: Train Loss so far: 0.039527870761230585
# Epoch 8, Batch 30: Train Loss so far: 0.04545670204873507
# Epoch 8, Batch 40: Train Loss so far: 0.04863557357166428
# Epoch 8, Batch 50: Train Loss so far: 0.04344781941967085
# Epoch 8, Batch 60: Train Loss so far: 0.04733320799617407
# Epoch 8, Batch 70: Train Loss so far: 0.04456587569355699
# Epoch 8, Batch 80: Train Loss so far: 0.04273504175216658
# Epoch 8, Batch 90: Train Loss so far: 0.04281977382100498
# Epoch 8, Batch 100: Train Loss so far: 0.04138056263909675
# Epoch 8, Batch 110: Train Loss so far: 0.041048587825868954
# Epoch 8, Batch 120: Train Loss so far: 0.042562160339245265
# Epoch 8, Batch 130: Train Loss so far: 0.04296853497284106
# Epoch 8, Batch 140: Train Loss so far: 0.05208416722931101
# Epoch 8, Batch 150: Train Loss so far: 0.052743799342618636
# Epoch 8, Batch 160: Train Loss so far: 0.05849486673905631
# Epoch 8, Batch 170: Train Loss so far: 0.06059251267750583
# Epoch 8, Batch 180: Train Loss so far: 0.06061182937442532
# Epoch 8, Batch 190: Train Loss so far: 0.06176441916276848
# Epoch 8, Batch 200: Train Loss so far: 0.06198684939357918
# Epoch 8, Batch 210: Train Loss so far: 0.06223814783761988
# Epoch 8, Batch 220: Train Loss so far: 0.06373471849523908
# Epoch 8, Batch 230: Train Loss so far: 0.06379492968452447
# Epoch 8, Batch 240: Train Loss so far: 0.06279511121538235
# Epoch 8, Batch 250: Train Loss so far: 0.06480175020778552
# Epoch 8, Batch 260: Train Loss so far: 0.06605082753409919
# Epoch 8, Batch 270: Train Loss so far: 0.06699838740621797
# Epoch 8, Batch 280: Train Loss so far: 0.06824209637582368
# Epoch 8, Batch 290: Train Loss so far: 0.06905702511852221
# Epoch 8, Batch 300: Train Loss so far: 0.06969481205916964
# Epoch 8, Batch 310: Train Loss so far: 0.0750557916272702
# Epoch 8, Batch 320: Train Loss so far: 0.08233833159065398
# Epoch 8, Batch 330: Train Loss so far: 0.08332066041537363
# Epoch 8, Batch 340: Train Loss so far: 0.08878940816126381
# Epoch 8, Batch 350: Train Loss so far: 0.09189243658345991
# Epoch 8, Batch 360: Train Loss so far: 0.09395325003845048
# Epoch 8, Batch 370: Train Loss so far: 0.09608245200030757
# Epoch 8, Batch 380: Train Loss so far: 0.09903969691214642
# Epoch 8, Batch 390: Train Loss so far: 0.10258859793374983
# Epoch 8, Batch 400: Train Loss so far: 0.10485131184599596
# Epoch 8, Batch 410: Train Loss so far: 0.10651010778738276
# Epoch 8, Batch 420: Train Loss so far: 0.10780326359090395
# Epoch 8, Batch 430: Train Loss so far: 0.10699024130725626
# Epoch 8, Batch 440: Train Loss so far: 0.1076008503412595
# Epoch 8, Batch 450: Train Loss so far: 0.10832139376990704
# Epoch 8, Batch 460: Train Loss so far: 0.10931156435196855
# Epoch 8, Validation Batch 10: Validation Loss so far: 1.6086862564086915
# Epoch 8, Validation Batch 20: Validation Loss so far: 1.8491389632225037
# Epoch 8, Validation Batch 30: Validation Loss so far: 1.8967725157737731
# Epoch 8, Validation Batch 40: Validation Loss so far: 1.9681066751480103
# Epoch 8, Validation Batch 50: Validation Loss so far: 1.918289691209793
# Epoch 8, Validation Batch 60: Validation Loss so far: 1.9708816101153692
# Epoch 8, Validation Batch 70: Validation Loss so far: 1.9488906460148947
# Epoch 8, Validation Batch 80: Validation Loss so far: 1.9512111082673074
# Epoch 8, Validation Batch 90: Validation Loss so far: 1.958849146631029
# Epoch 8, Validation Batch 100: Validation Loss so far: 1.9402938976883888
# Epoch 8, Validation Batch 110: Validation Loss so far: 1.9443438055840405
# Epoch 8: Train Loss: 0.11008885530420168, Val Loss: 1.9457612182849493, Val Accuracy: 57.11982804943579%
# Epoch 9, Batch 10: Train Loss so far: 0.11261709220707417
# Epoch 9, Batch 20: Train Loss so far: 0.1296712136361748
# Epoch 9, Batch 30: Train Loss so far: 0.10758082568645477
# Epoch 9, Batch 40: Train Loss so far: 0.09563165153376758
# Epoch 9, Batch 50: Train Loss so far: 0.09785769257694482
# Epoch 9, Batch 60: Train Loss so far: 0.09051659616331259
# Epoch 9, Batch 70: Train Loss so far: 0.08571234274921673
# Epoch 9, Batch 80: Train Loss so far: 0.08865715034771711
# Epoch 9, Batch 90: Train Loss so far: 0.08696190800983458
# Epoch 9, Batch 100: Train Loss so far: 0.08332184851402417
# Epoch 9, Batch 110: Train Loss so far: 0.08259972470431504
# Epoch 9, Batch 120: Train Loss so far: 0.0861291476234328
# Epoch 9, Batch 130: Train Loss so far: 0.0819781460118695
# Epoch 9, Batch 140: Train Loss so far: 0.08031481496124927
# Epoch 9, Batch 150: Train Loss so far: 0.08000286267139017
# Epoch 9, Batch 160: Train Loss so far: 0.07863021019438747
# Epoch 9, Batch 170: Train Loss so far: 0.07801948308342081
# Epoch 9, Batch 180: Train Loss so far: 0.07569929404029002
# Epoch 9, Batch 190: Train Loss so far: 0.07552502190351094
# Epoch 9, Batch 200: Train Loss so far: 0.07593437749659643
# Epoch 9, Batch 210: Train Loss so far: 0.07492574096346895
# Epoch 9, Batch 220: Train Loss so far: 0.074905548163224
# Epoch 9, Batch 230: Train Loss so far: 0.07472962288935062
# Epoch 9, Batch 240: Train Loss so far: 0.07334943041108394
# Epoch 9, Batch 250: Train Loss so far: 0.07498313943389803
# Epoch 9, Batch 260: Train Loss so far: 0.07336322814673901
# Epoch 9, Batch 270: Train Loss so far: 0.0758454285191234
# Epoch 9, Batch 280: Train Loss so far: 0.07662657922815665
# Epoch 9, Batch 290: Train Loss so far: 0.07801440214850651
# Epoch 9, Batch 300: Train Loss so far: 0.07842989456839859
# Epoch 9, Batch 310: Train Loss so far: 0.07974613128951
# Epoch 9, Batch 320: Train Loss so far: 0.0802442257583607
# Epoch 9, Batch 330: Train Loss so far: 0.08070796466234958
# Epoch 9, Batch 340: Train Loss so far: 0.08047164764857906
# Epoch 9, Batch 350: Train Loss so far: 0.07955272819381207
# Epoch 9, Batch 360: Train Loss so far: 0.08134705833249932
# Epoch 9, Batch 370: Train Loss so far: 0.08201521339738188
# Epoch 9, Batch 380: Train Loss so far: 0.08160098121244166
# Epoch 9, Batch 390: Train Loss so far: 0.0817001586773982
# Epoch 9, Batch 400: Train Loss so far: 0.08113937992078718
# Epoch 9, Batch 410: Train Loss so far: 0.081283622559319
# Epoch 9, Batch 420: Train Loss so far: 0.08103698424861899
# Epoch 9, Batch 430: Train Loss so far: 0.0809281665333655
# Epoch 9, Batch 440: Train Loss so far: 0.08014871796529571
# Epoch 9, Batch 450: Train Loss so far: 0.07934302900400426
# Epoch 9, Batch 460: Train Loss so far: 0.07931874609734539
# Epoch 9, Validation Batch 10: Validation Loss so far: 1.502877151966095
# Epoch 9, Validation Batch 20: Validation Loss so far: 1.9661356151103973
# Epoch 9, Validation Batch 30: Validation Loss so far: 1.9283385554949442
# Epoch 9, Validation Batch 40: Validation Loss so far: 2.033875769376755
# Epoch 9, Validation Batch 50: Validation Loss so far: 1.9635504162311554
# Epoch 9, Validation Batch 60: Validation Loss so far: 2.0215118298927943
# Epoch 9, Validation Batch 70: Validation Loss so far: 2.024367044653211
# Epoch 9, Validation Batch 80: Validation Loss so far: 1.9976497992873192
# Epoch 9, Validation Batch 90: Validation Loss so far: 2.01490408844418
# Epoch 9, Validation Batch 100: Validation Loss so far: 1.991594484448433
# Epoch 9, Validation Batch 110: Validation Loss so far: 2.0050086931748825
# Epoch 9: Train Loss: 0.0792764601899239, Val Loss: 2.0070740753768854, Val Accuracy: 60.29016657710908%
# Epoch 10, Batch 10: Train Loss so far: 0.0658620490692556
# Epoch 10, Batch 20: Train Loss so far: 0.061057859030552206
# Epoch 10, Batch 30: Train Loss so far: 0.05998403602279723
# Epoch 10, Batch 40: Train Loss so far: 0.0568219821434468
# Epoch 10, Batch 50: Train Loss so far: 0.06281417589634657
# Epoch 10, Batch 60: Train Loss so far: 0.05959295493667014
# Epoch 10, Batch 70: Train Loss so far: 0.06036276054801419
# Epoch 10, Batch 80: Train Loss so far: 0.07178699852520368
# Epoch 10, Batch 90: Train Loss so far: 0.08359360205811552
# Epoch 10, Batch 100: Train Loss so far: 0.09671500016353093
# Epoch 10, Batch 110: Train Loss so far: 0.10923804119546814
# Epoch 10, Batch 120: Train Loss so far: 0.11775490878984177
# Epoch 10, Batch 130: Train Loss so far: 0.12385442335642158
# Epoch 10, Batch 140: Train Loss so far: 0.12383836389303074
# Epoch 10, Batch 150: Train Loss so far: 0.12300794138805941
# Epoch 10, Batch 160: Train Loss so far: 0.12001869850137155
# Epoch 10, Batch 170: Train Loss so far: 0.12142571861075019
# Epoch 10, Batch 180: Train Loss so far: 0.123658585139007
# Epoch 10, Batch 190: Train Loss so far: 0.12245556801790372
# Epoch 10, Batch 200: Train Loss so far: 0.12423381468222942
# Epoch 10, Batch 210: Train Loss so far: 0.12113882083656444
# Epoch 10, Batch 220: Train Loss so far: 0.12079683420385912
# Epoch 10, Batch 230: Train Loss so far: 0.11995051865030647
# Epoch 10, Batch 240: Train Loss so far: 0.11949326762163158
# Epoch 10, Batch 250: Train Loss so far: 0.11847209610650315
# Epoch 10, Batch 260: Train Loss so far: 0.12155413102367535
# Epoch 10, Batch 270: Train Loss so far: 0.12242063117532612
# Epoch 10, Batch 280: Train Loss so far: 0.12142129741218273
# Epoch 10, Batch 290: Train Loss so far: 0.11958066963566595
# Epoch 10, Batch 300: Train Loss so far: 0.11791005362135669
# Epoch 10, Batch 310: Train Loss so far: 0.11683770913570639
# Epoch 10, Batch 320: Train Loss so far: 0.11646126716805157
# Epoch 10, Batch 330: Train Loss so far: 0.11625472684108624
# Epoch 10, Batch 340: Train Loss so far: 0.11584168281817042
# Epoch 10, Batch 350: Train Loss so far: 0.11353200936689972
# Epoch 10, Batch 360: Train Loss so far: 0.11267677275205237
# Epoch 10, Batch 370: Train Loss so far: 0.11083221644465183
# Epoch 10, Batch 380: Train Loss so far: 0.10978316577200435
# Epoch 10, Batch 390: Train Loss so far: 0.11104905172609365
# Epoch 10, Batch 400: Train Loss so far: 0.11063781535951421
# Epoch 10, Batch 410: Train Loss so far: 0.10977346853171362
# Epoch 10, Batch 420: Train Loss so far: 0.10892560171916904
# Epoch 10, Batch 430: Train Loss so far: 0.10786410670532563
# Epoch 10, Batch 440: Train Loss so far: 0.10650662981153636
# Epoch 10, Batch 450: Train Loss so far: 0.10553048548443864
# Epoch 10, Batch 460: Train Loss so far: 0.10489896619844291
# Epoch 10, Validation Batch 10: Validation Loss so far: 1.6180143713951112
# Epoch 10, Validation Batch 20: Validation Loss so far: 2.05145605802536
# Epoch 10, Validation Batch 30: Validation Loss so far: 2.085722249746323
# Epoch 10, Validation Batch 40: Validation Loss so far: 2.110890309512615
# Epoch 10, Validation Batch 50: Validation Loss so far: 2.0825948834419252
# Epoch 10, Validation Batch 60: Validation Loss so far: 2.102538425723712
# Epoch 10, Validation Batch 70: Validation Loss so far: 2.1031966601099286
# Epoch 10, Validation Batch 80: Validation Loss so far: 2.090433817356825
# Epoch 10, Validation Batch 90: Validation Loss so far: 2.0898171100351544
# Epoch 10, Validation Batch 100: Validation Loss so far: 2.0639501786231995
# Epoch 10, Validation Batch 110: Validation Loss so far: 2.0799840742891487
# Epoch 10: Train Loss: 0.10427903719875929, Val Loss: 2.0802448188137803, Val Accuracy: 59.430413756045134%

# %% [markdown]
# #### Print all details about emotions

# %%
import torch

def test_model_detailed(model, test_loader, num_classes):
    model.eval()  # Set the model to evaluation mode
    correct_count = [0] * num_classes
    total_count = [0] * num_classes
    total_correct = 0
    total_samples = 0

    with torch.no_grad():  # Turn off gradients for validation, saves memory and computations
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            correct_predictions = (predicted == labels)

            # Update per-class statistics
            for label, prediction in zip(labels, predicted):
                total_count[label] += 1
                if label == prediction:
                    correct_count[label] += 1
            
            # Update total statistics
            total_correct += correct_predictions.sum().item()
            total_samples += labels.size(0)
    
    overall_accuracy = 100 * total_correct / total_samples
    print(f'Test Accuracy: {overall_accuracy:.2f}%')

    return correct_count, total_count, overall_accuracy
    
correct_count, total_count, overall_accuracy = test_model_detailed(model, test_loader, num_classes=7)
incorrect_count = [total_count[i] - correct_count[i] for i in range(len(total_count))]

# %%
# Define the emotions labels
emotions = ['happy', 'sad', 'fearful', 'neutral', 'angry', 'disgusted', 'surprised']

# Define the width of the bars
bar_width = 0.35

# Define the x-axis positions for the bars
x = range(len(emotions))

# Plotting the bars for correct counts
plt.bar(x, correct_count, width=bar_width, label='Correct', color='green')

# Plotting the bars for incorrect counts
plt.bar([i + bar_width for i in x], incorrect_count, width=bar_width, label='Incorrect', color='red')

# Adding labels, title, and custom x-axis tick labels
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.title('Classification Correctness by Emotion')
plt.xticks([i + bar_width / 2 for i in x], emotions, rotation=45)
plt.legend()

# Display the plot
plt.show()
